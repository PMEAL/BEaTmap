# %%
import beatmap as bt
import numpy as np
import pandas as pd
from ipywidgets import interact, interactive, fixed, widgets
from IPython.display import HTML, Javascript, display

HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to show/hide raw code"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to show/hide raw code"></form>

# %% [markdown]
# BET Background

# %% [markdown]
# EXAMPLE DATA SET
#
# MENTION IMPORTING FROM .csv (OR LET USER CHOOSE TO USE EXAMPLE DATA OR IMPORT THEIR OWN)

# %%
#cyclohexane adsorption on vulcan xc-72
relp = [0.001, 0.00994, 0.01966, 0.02988, 0.04012, 0.05014, 0.0599, 0.07006, 0.08008, 0.09, 0.09996, 0.125, 0.14998, 0.17496, 0.20004, 0.22492, 0.25006, 0.27494, 0.3, 0.34996, 0.39984, 0.44986, 0.49984, 0.54994, 0.60008, 0.69974, 0.79978, 0.90036]
n = [0.0000002, 0.00037527, 0.000472421, 0.000538363, 0.00058616, 0.000622651, 0.000652, 0.000677117, 0.000698477, 0.000717061, 0.000734596, 0.000768176, 0.00079749, 0.000821287, 0.00084302, 0.000863093, 0.000882354, 0.000899077, 0.00091827, 0.000951308, 0.000986581, 0.001020669, 0.001059868, 0.001103637, 0.001147778, 0.001275768, 0.001479008, 0.001906848]
dict_from_lists = {'relp': relp, 'n':n}
data = pd.DataFrame(dict_from_lists)
data['bet'] = (1 / data.n) * (data.relp / (1-data.relp))
data['check1'] = data.n * (1 - data.relp)

#checking data quality
test = np.zeros(len(data))
minus1 = np.concatenate(([0], data.n[: -1]))
test = data.n - minus1
test_sum = sum(x < 0 for x in test)
if test_sum > 0:
    print("""\nIsotherm data is suspect.
Adsorbed moles do not consistantly increase as relative pressure increases""")
else:
    print("""\nIsotherm data quality appears good.
Adsorbed molar amounts are increasing as relative pressure increases.""")
file = 'example_data.xxx'
adsorbate = 'cyclohexane'
a_o = 39

sa, c, nm, err, linreg = bt.core.bet(data, a_o)
# Out:
# Isotherm data quality appears good.
# Adsorbed molar amounts are increasing as relative pressure increases.

# %%
mask_picker = interactive(bt.core.combine_masks, df=fixed(data), linreg=fixed(linreg), nm=fixed(nm), check1=True, check2=True, check3=True, check4=True, check5=True, points = (1,len(data),1))
display(mask_picker)
# Out:
# interactive(children=(Checkbox(value=True, description='check1'), Checkbox(value=True, description='check2'), …

# %%
def run_all(ev):
    display(Javascript('IPython.notebook.execute_cell_range(IPython.notebook.get_selected_index()+1, IPython.notebook.ncells())'))    
    
button = widgets.Button(description="Update checks")
button.on_click(run_all)
display(button)
# Out:
# Button(description='Update checks', style=ButtonStyle())

# %%
masked_sa = np.multiply(sa, mask_picker.result)
masked_c = np.multiply(c, mask_picker.result)
masked_nm = np.multiply(nm, mask_picker.result)
masked_error = np.multiply(err, mask_picker.result)

bt.vis.ssa_heatmap(data, masked_sa, file)
bt.vis.err_heatmap(data, masked_error, file)
bt.vis.bet_combo_plot(masked_c, masked_error, data, file)
bt.vis.bet_iso_combo_plot(masked_c, masked_error, masked_sa, masked_nm, data, file)
# Out:
# Specific surface area heatmap saved as: ssa_heatmap_example_data.png
# Error heatmap saved as: error_heatmap_example_data.png
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-53d72f1b4977> in <module>
#       6 bt.vis.ssa_heatmap(data, masked_sa, file)
#       7 bt.vis.err_heatmap(data, masked_error, file)
# ----> 8 bt.vis.bet_combo_plot(masked_c, masked_error, data, file)
#       9 bt.vis.bet_iso_combo_plot(masked_c, masked_error, masked_sa, masked_nm, data, file)
#
# ~/OneDrive - University of Waterloo/beatmap/beatmap/vis/_figures.py in bet_combo_plot(c, err, df, file_name)
#     334     ax1.set_xlim(min_linex[0]-.01, min_linex[1]+.01)
#     335     ax1.set_ylabel('1/[n(1-Po/P)]')
# --> 336     ax1.set_ylim(min_liney[0]*.9, min_liney[1]*1.1)
#     337     ax1.set_xlabel('P/Po')
#     338     ax1.grid(b=True, which='major', color='gray', linestyle='-')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    3620
#    3621         self._process_unit_info(ydata=(bottom, top))
# -> 3622         bottom = self._validate_converted_limits(bottom, self.convert_yunits)
#    3623         top = self._validate_converted_limits(top, self.convert_yunits)
#    3624
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _validate_converted_limits(self, limit, convert)
#    3156             if (isinstance(converted_limit, Real)
#    3157                     and not np.isfinite(converted_limit)):
# -> 3158                 raise ValueError("Axis limits cannot be NaN or Inf")
#    3159             return converted_limit
#    3160
#
# ValueError: Axis limits cannot be NaN or Inf

# %%
#settables.ascii_tables(masked_c, masked_ssa, masked_error, df)
